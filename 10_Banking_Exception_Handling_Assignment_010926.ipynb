# %% [markdown]
# # Banking Assignment — Exception Handling (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice try/except, custom exceptions, chaining, cleanup, resilient batch processing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Parse a deposit amount for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1001
account_ref = "ACC-1001"
try:
    amount = int(input("Enter deposit amount: "))
    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Deposit successful:", amount, "for", account_ref)
except ValueError as e:
    print("Invalid deposit:", e)
# Out:
# Invalid input for ACC-1001 :invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ### Q2. Handle a missing account key for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1002
accounts = {"ACC-1001": 1000, "ACC-1003": 2000}
account_ref = "ACC-1002"
try:
    print("Balance:", accounts[account_ref])
except KeyError:
    print(account_ref, ": Account not found.")
# Out:
# Invalid input: 'Account ACC-1002 does not exist.'

# %% [markdown]
# ### Q3. Prevent division by zero in average balance for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1003
total_balance = 20000
account_count = 0
try:
    average = total_balance / account_count
    print("Average balance:", average)
except ZeroDivisionError:
    print(ref if False else "ACC-1003", ": Cannot calculate average with zero accounts.")
# Out:
# No accounts available to calculate the average balance.

# %% [markdown]
# ### Q4. Open a transaction file safely for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1004
file_name = "transactions.txt"
try:
    with open(file_name, "r", encoding="utf-8") as file:
        data = file.readlines()
    print("Transactions read:", len(data))
except FileNotFoundError:
    print("ACC-1004: Transaction file not found.")
# Out:
# File not found: transactions.txt

# %% [markdown]
# ### Q5. Reject a negative withdrawal for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1005
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")
    print("ACC-1005: Withdrawal amount accepted =", amount)
except ValueError as e:
    print("ACC-1005:", e)
# Out:
# Invalid input: Withdrawal amount cannot be less than zero.

# %% [markdown]
# ### Q6. Catch invalid tenure input for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1006
try:
    tenure = int(input("Enter tenure in years: "))
    print("ACC-1006: Tenure =", tenure)
except ValueError:
    print("ACC-1006: Tenure must be an integer.")
# Out:
# Invalid input: Tenure must be an integer.

# %% [markdown]
# ### Q7. Use else after pin-format validation for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1007
pin = input("Enter 4-digit PIN: ")
try:
    if not pin.isdigit() or len(pin) != 4:
        raise ValueError("PIN must contain exactly 4 digits.")
except ValueError as e:
    print("ACC-1007:", e)
else:
    print("ACC-1007: PIN format is valid.")
# Out:
# Invalid input: invalid literal for int() with base 10: 'acdf'

# %% [markdown]
# ### Q8. Use finally to close a session for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1008
try:
    print("ACC-1008: Session started.")
    amount = int(input("Enter amount: "))
    print("ACC-1008: Amount entered =", amount)
except ValueError:
    print("ACC-1008: Invalid amount.")
finally:
    print("ACC-1008: Session closed.")
# Out:
# 500 has been successfully credited
# Session is closed. Thank you for banking with us.

# %% [markdown]
# ### Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1009
try:
    amount = int(input("Enter amount: "))
    balance = float(input("Enter balance: "))
    print("ACC-1009: Amount =", amount, "Balance =", balance)
except (ValueError, TypeError) as e:
    print("ACC-1009: Numeric conversion error -", e)
# Out:
# ACC-1009: Insufficient funds
# ACC-1009: session completed.

# %% [markdown]
# ### Q10. Raise a clear valueerror for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1010
balance = 5000
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount <= 0:
        raise ValueError("Withdrawal amount must be greater than zero.")
    if amount > balance:
        raise ValueError("Insufficient funds.")
    balance -= amount
    print("ACC-1010: New balance =", balance)
except ValueError as e:
    print("ACC-1010:", e)
# Out:
# ACC-1010: invalid literal for int() with base 10: '22.55'
# ACC-1010: Transaction attempt complete

# %% [markdown]
# ### Q11. Parse a deposit amount for banking case 2; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1011
account_ref = "ACC-1011"
try:
    amount = int(input("Enter deposit amount: "))
    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Deposit successful:", amount, "for", account_ref)
except ValueError as e:
    print("Invalid deposit:", e)
# Out:
# ACC-1011: invalid literal for int() with base 10: ''
# ACC-1011: Transaction attempt complete

# %% [markdown]
# ### Q12. Handle a missing account key for banking case 2; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1012
accounts = {"ACC-1001": 1000, "ACC-1003": 2000}
account_ref = "ACC-1012"
try:
    print("Balance:", accounts[account_ref])
except KeyError:
    print(account_ref, ": Account not found.")
# Out:
# ACC-1012: Account not found
# ACC-1012: Transaction attempt complete

# %% [markdown]
# ### Q13. Prevent division by zero in average balance for banking case 2; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1013
total_balance = 20000
account_count = 0
try:
    average = total_balance / account_count
    print("Average balance:", average)
except ZeroDivisionError:
    print(ref if False else "ACC-1013", ": Cannot calculate average with zero accounts.")
# Out:
# Average balance: 4000.0
# ACC-1013: Transaction attempt complete

# %% [markdown]
# ### Q14. Open a transaction file safely for banking case 2; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1014
file_name = "transactions.txt"
try:
    with open(file_name, "r", encoding="utf-8") as file:
        data = file.readlines()
    print("Transactions read:", len(data))
except FileNotFoundError:
    print("ACC-1014: Transaction file not found.")
# Out:
# ACC-1014 : Transaction file not found
# ACC-1014 : File handling attempt complete

# %% [markdown]
# ### Q15. Reject a negative withdrawal for banking case 2; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1015
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")
    print("ACC-1015: Withdrawal amount accepted =", amount)
except ValueError as e:
    print("ACC-1015:", e)
# Out:
# ACC-1015: Withdrawal cannot be negative
# ACC-1015: Transaction attempt complete

# %% [markdown]
# ### Q16. Catch invalid tenure input for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1016
try:
    tenure = int(input("Enter tenure in years: "))
    print("ACC-1016: Tenure =", tenure)
except ValueError:
    print("ACC-1016: Tenure must be an integer.")
# Out:
# ACC-1016 : invalid literal for int() with base 10: 'khg'
# ACC-1016 : Transaction attempt complete

# %% [markdown]
# ### Q17. Use else after pin-format validation for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1017
pin = input("Enter 4-digit PIN: ")
try:
    if not pin.isdigit() or len(pin) != 4:
        raise ValueError("PIN must contain exactly 4 digits.")
except ValueError as e:
    print("ACC-1017:", e)
else:
    print("ACC-1017: PIN format is valid.")
# Out:
# ACC-1017 : PIN must be 4 digits
# ACC-1017 : Validation attempt complete

# %% [markdown]
# ### Q18. Use finally to close a session for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1018
try:
    print("ACC-1018: Session started.")
    amount = int(input("Enter amount: "))
    print("ACC-1018: Amount entered =", amount)
except ValueError:
    print("ACC-1018: Invalid amount.")
finally:
    print("ACC-1018: Session closed.")
# Out:
# ACC-1018 : PIN must be 4 digits
# ACC-1018 : Session closed

# %% [markdown]
# ### Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1019
try:
    amount = int(input("Enter amount: "))
    balance = float(input("Enter balance: "))
    print("ACC-1019: Amount =", amount, "Balance =", balance)
except (ValueError, TypeError) as e:
    print("ACC-1019: Numeric conversion error -", e)
# Out:
# ACC-1019 : Value error - Insufficient funds
# ACC-1019 : Transaction attempt complete

# %% [markdown]
# ### Q20. Raise a clear valueerror for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1020
balance = 5000
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount <= 0:
        raise ValueError("Withdrawal amount must be greater than zero.")
    if amount > balance:
        raise ValueError("Insufficient funds.")
    balance -= amount
    print("ACC-1020: New balance =", balance)
except ValueError as e:
    print("ACC-1020:", e)
# Out:
# ACC-1020: Insufficient funds.

# %% [markdown]
# ### Q21. Parse a deposit amount for banking case 3; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1021
account_ref = "ACC-1021"
try:
    amount = int(input("Enter deposit amount: "))
    if amount <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Deposit successful:", amount, "for", account_ref)
except ValueError as e:
    print("Invalid deposit:", e)
# Out:
# Deposit successful: 5200 for ACC-1021

# %% [markdown]
# ### Q22. Handle a missing account key for banking case 3; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1022
accounts = {"ACC-1001": 1000, "ACC-1003": 2000}
account_ref = "ACC-1022"
try:
    print("Balance:", accounts[account_ref])
except KeyError:
    print(account_ref, ": Account not found.")
# Out:
# ACC-1022 : Account not found.

# %% [markdown]
# ### Q23. Prevent division by zero in average balance for banking case 3; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1023
total_balance = 20000
account_count = 0
try:
    average = total_balance / account_count
    print("Average balance:", average)
except ZeroDivisionError:
    print(ref if False else "ACC-1023", ": Cannot calculate average with zero accounts.")
# Out:
# ACC-1023 : Cannot calculate average with zero accounts.

# %% [markdown]
# ### Q24. Open a transaction file safely for banking case 3; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1024
file_name = "transactions.txt"
try:
    with open(file_name, "r", encoding="utf-8") as file:
        data = file.readlines()
    print("Transactions read:", len(data))
except FileNotFoundError:
    print("ACC-1024: Transaction file not found.")
# Out:
# ACC-1024: Transaction file not found.

# %% [markdown]
# ### Q25. Reject a negative withdrawal for banking case 3; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1025
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")
    print("ACC-1025: Withdrawal amount accepted =", amount)
except ValueError as e:
    print("ACC-1025:", e)
# Out:
# ACC-1025: invalid literal for int() with base 10: 'NJHU'

# %% [markdown]
# ### Q26. Catch invalid tenure input for banking case 3; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1026
try:
    tenure = int(input("Enter tenure in years: "))
    print("ACC-1026: Tenure =", tenure)
except ValueError:
    print("ACC-1026: Tenure must be an integer.")
# Out:
# ACC-1026: Tenure must be an integer.

# %% [markdown]
# ### Q27. Use else after pin-format validation for banking case 3; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1027
pin = input("Enter 4-digit PIN: ")
try:
    if not pin.isdigit() or len(pin) != 4:
        raise ValueError("PIN must contain exactly 4 digits.")
except ValueError as e:
    print("ACC-1027:", e)
else:
    print("ACC-1027: PIN format is valid.")
# Out:
# ACC-1027: PIN must contain exactly 4 digits.

# %% [markdown]
# ### Q28. Use finally to close a session for banking case 3; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1028
try:
    print("ACC-1028: Session started.")
    amount = int(input("Enter amount: "))
    print("ACC-1028: Amount entered =", amount)
except ValueError:
    print("ACC-1028: Invalid amount.")
finally:
    print("ACC-1028: Session closed.")
# Out:
# ACC-1028: Session started.
# ACC-1028: Invalid amount.
# ACC-1028: Session closed.

# %% [markdown]
# ### Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1029
try:
    amount = int(input("Enter amount: "))
    balance = float(input("Enter balance: "))
    print("ACC-1029: Amount =", amount, "Balance =", balance)
except (ValueError, TypeError) as e:
    print("ACC-1029: Numeric conversion error -", e)
# Out:
# ACC-1029: Amount = 6520 Balance = 456.0

# %% [markdown]
# ### Q30. Raise a clear valueerror for banking case 3; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1030
balance = 5000
try:
    amount = int(input("Enter withdrawal amount: "))
    if amount <= 0:
        raise ValueError("Withdrawal amount must be greater than zero.")
    if amount > balance:
        raise ValueError("Insufficient funds.")
    balance -= amount
    print("ACC-1030: New balance =", balance)
except ValueError as e:
    print("ACC-1030:", e)
# Out:
# ACC-1030: New balance = 3000

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Create insufficientfundserror for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1031
class InsufficientFundsError(Exception):
    pass

balance = 5000
withdrawal = 6000
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("ACC-1031:", e)
# Out:
# ACC-1031: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1032
class InvalidTransactionError(Exception):
    pass

def make_transfer(amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        return amount
    except ValueError as e:
        raise InvalidTransactionError("Invalid transfer amount.") from e

try:
    print("Transfer:", make_transfer("abc"))
except InvalidTransactionError as e:
    print("ACC-1032:", e)
    print("Original cause:", type(e.__cause__).__name__)

# %% [markdown]
# ### Q33. Process transfers while isolating bad rows for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1033
transfers = [1000, "bad", 500, -200, 300]
successful = []
failed = []

for amount in transfers:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        successful.append(amount)
    except (ValueError, TypeError) as e:
        failed.append((amount, str(e)))

print("ACC-1033: Successful =", successful)
print("ACC-1033: Failed =", failed)
# Out:
# ACC-1033: Successful = [1000.0, 500.0, 300.0]
# ACC-1033: Failed = [('bad', "could not convert string to float: 'bad'"), (-200.0, 'Amount must be positive')]

# %% [markdown]
# ### Q34. Retry a transient payment gateway for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1034
class TemporaryGatewayError(Exception):
    pass

attempts = 0
max_attempts = 3

while attempts < max_attempts:
    attempts += 1
    try:
        if attempts < 3:
            raise TemporaryGatewayError("Gateway temporarily unavailable")
        print("ACC-1034: Payment successful on attempt", attempts)
        break
    except TemporaryGatewayError as e:
        print("ACC-1034: Attempt", attempts, "failed")
else:
    print("ACC-1034: Payment failed after retries.")

# %% [markdown]
# ### Q35. Log failed standing instructions for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1035
standing_instructions = [
    ("SI-01", 1000, True),
    ("SI-02", 500, False),
    ("SI-03", 750, True)
]
failed = []

for ref_id, amount, success in standing_instructions:
    try:
        if not success:
            raise RuntimeError("Standing instruction failed")
        print("Processed:", ref_id, amount)
    except RuntimeError as e:
        failed.append((ref_id, str(e)))

print("ACC-1035: Failed instructions =", failed)
# Out:
# Processed: SI-01 1000
# Processed: SI-03 750
# ACC-1035: Failed instructions = [('SI-02', 'Standing instruction failed')]

# %% [markdown]
# ### Q36. Return a structured failure result for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1036
def withdraw(balance, amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > balance:
            raise ValueError("Insufficient funds")
        return {"status": "success", "balance": balance - amount}
    except (ValueError, TypeError) as e:
        return {"status": "failed", "error": str(e)}

print("ACC-1036:", withdraw(5000, 6000))
# Out:
# ACC-1036: {'status': 'failed', 'error': 'Insufficient funds'}

# %% [markdown]
# ### Q37. Validate a nested beneficiary record for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1037
beneficiary = {
    "details": {"name": "Ravi", "account": "ACC-2001"}
}
try:
    name = beneficiary["details"]["name"]
    account = beneficiary["details"]["account"]
    if not name or not account:
        raise ValueError("Beneficiary details are incomplete.")
    print("ACC-1037: Beneficiary valid:", name, account)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1037:", e)
# Out:
# ACC-1037: Beneficiary valid: Ravi ACC-2001

# %% [markdown]
# ### Q38. Use a context manager for an audit file for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1038
file_name = "ACC-1038_audit.txt"
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write("Audit entry for ACC-1038\n")
    print("ACC-1038: Audit file handled safely.")
except OSError as e:
    print("ACC-1038: File error -", e)
# Out:
# ACC-1038: Audit file handled safely.

# %% [markdown]
# ### Q39. Separate validation and recovery for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1039
def validate_amount(value):
    try:
        value = float(value)
        if value <= 0:
            raise ValueError("Amount must be positive")
        return value
    except (ValueError, TypeError) as e:
        print("ACC-1039: Validation failed -", e)
        return None

def recover_amount(value):
    amount = validate_amount(value)
    if amount is None:
        print("ACC-1039: Recovery: transaction cancelled safely.")
        return False
    print("ACC-1039: Recovery not needed. Amount =", amount)
    return True

recover_amount("-100")
# Out:
# ACC-1039: Validation failed - Amount must be positive
# ACC-1039: Recovery: transaction cancelled safely.
# False

# %% [markdown]
# ### Q40. Collect all kyc validation errors for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1040
kyc = {"name": "", "age": 15, "pan": ""}
errors = []

if not kyc.get("name"):
    errors.append("Name is required")
if not isinstance(kyc.get("age"), int) or kyc["age"] < 18:
    errors.append("Age must be 18 or above")
if not kyc.get("pan"):
    errors.append("PAN is required")
if errors:
    print("ACC-1040: KYC errors =", errors)
else:
    print("ACC-1040: KYC validation passed.")
# Out:
# ACC-1040: KYC errors = ['Name is required', 'Age must be 18 or above', 'PAN is required']

# %% [markdown]
# ### Q41. Create insufficientfundserror for banking case 2; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1041
class InsufficientFundsError(Exception):
    pass
balance = 5000
withdrawal = 6000
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("ACC-1041:", e)
# Out:
# ACC-1041: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1042
class InvalidTransactionError(Exception):
    pass
def make_transfer(amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        return amount
    except ValueError as e:
        raise InvalidTransactionError("Invalid transfer amount.") from e
try:
    print("Transfer:", make_transfer("abc"))
except InvalidTransactionError as e:
    print("ACC-1042:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# ACC-1042: Invalid transfer amount.
# Original cause: ValueError

# %% [markdown]
# ### Q43. Process transfers while isolating bad rows for banking case 2; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1043
transfers = [1000, "bad", 500, -200, 300]
successful = []
failed = []
for amount in transfers:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        successful.append(amount)
    except (ValueError, TypeError) as e:
        failed.append((amount, str(e)))
print("ACC-1043: Successful =", successful)
print("ACC-1043: Failed =", failed)
# Out:
# ACC-1043: Successful = [1000.0, 500.0, 300.0]
# ACC-1043: Failed = [('bad', "could not convert string to float: 'bad'"), (-200.0, 'Amount must be positive')]

# %% [markdown]
# ### Q44. Retry a transient payment gateway for banking case 2; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1044
class TemporaryGatewayError(Exception):
    pass
attempts = 0
max_attempts = 3
while attempts < max_attempts:
    attempts += 1
    try:
        if attempts < 3:
            raise TemporaryGatewayError("Gateway temporarily unavailable")
        print("ACC-1044: Payment successful on attempt", attempts)
        break
    except TemporaryGatewayError as e:
        print("ACC-1044: Attempt", attempts, "failed")
else:
    print("ACC-1044: Payment failed after retries.")
# Out:
# ACC-1044: Attempt 1 failed
# ACC-1044: Attempt 2 failed
# ACC-1044: Payment successful on attempt 3

# %% [markdown]
# ### Q45. Log failed standing instructions for banking case 2; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1045
standing_instructions = [
    ("SI-01", 1000, True),
    ("SI-02", 500, False),
    ("SI-03", 750, True)
]
failed = []
for ref_id, amount, success in standing_instructions:
    try:
        if not success:
            raise RuntimeError("Standing instruction failed")
        print("Processed:", ref_id, amount)
    except RuntimeError as e:
        failed.append((ref_id, str(e)))

print("ACC-1045: Failed instructions =", failed)
# Out:
# Processed: SI-01 1000
# Processed: SI-03 750
# ACC-1045: Failed instructions = [('SI-02', 'Standing instruction failed')]

# %% [markdown]
# ### Q46. Return a structured failure result for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1046
def withdraw(balance, amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > balance:
            raise ValueError("Insufficient funds")
        return {"status": "success", "balance": balance - amount}
    except (ValueError, TypeError) as e:
        return {"status": "failed", "error": str(e)}
print("ACC-1046:", withdraw(5000, 6000))
# Out:
# ACC-1046: {'status': 'failed', 'error': 'Insufficient funds'}

# %% [markdown]
# ### Q47. Validate a nested beneficiary record for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1047
beneficiary = {
    "details": {"name": "Ravi", "account": "ACC-2001"}
}
try:
    name = beneficiary["details"]["name"]
    account = beneficiary["details"]["account"]
    if not name or not account:
        raise ValueError("Beneficiary details are incomplete.")
    print("ACC-1047: Beneficiary valid:", name, account)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1047:", e)
# Out:
# ACC-1047: Beneficiary valid: Ravi ACC-2001

# %% [markdown]
# ### Q48. Use a context manager for an audit file for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1048
file_name = "ACC-1048_audit.txt"
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write("Audit entry for ACC-1048\n")
    print("ACC-1048: Audit file handled safely.")
except OSError as e:
    print("ACC-1048: File error -", e)
# Out:
# ACC-1048: Audit file handled safely.

# %% [markdown]
# ### Q49. Separate validation and recovery for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1049
def validate_amount(value):
    try:
        value = float(value)
        if value <= 0:
            raise ValueError("Amount must be positive")
        return value
    except (ValueError, TypeError) as e:
        print("ACC-1049: Validation failed -", e)
        return None
def recover_amount(value):
    amount = validate_amount(value)
    if amount is None:
        print("ACC-1049: Recovery: transaction cancelled safely.")
        return False
    print("ACC-1049: Recovery not needed. Amount =", amount)
    return True

recover_amount("-100")
# Out:
# ACC-1049: Validation failed - Amount must be positive
# ACC-1049: Recovery: transaction cancelled safely.
# False

# %% [markdown]
# ### Q50. Collect all kyc validation errors for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1050
kyc = {"name": "", "age": 15, "pan": ""}
errors = []
if not kyc.get("name"):
    errors.append("Name is required")
if not isinstance(kyc.get("age"), int) or kyc["age"] < 18:
    errors.append("Age must be 18 or above")
if not kyc.get("pan"):
    errors.append("PAN is required")
if errors:
    print("ACC-1050: KYC errors =", errors)
else:
    print("ACC-1050: KYC validation passed.")
# Out:
# ACC-1050: KYC errors = ['Name is required', 'Age must be 18 or above', 'PAN is required']

# %% [markdown]
# ### Q51. Create insufficientfundserror for banking case 3; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1051
class InsufficientFundsError(Exception):
    pass
balance = 5000
withdrawal = 6000
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("ACC-1051:", e)
# Out:
# ACC-1051: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1052
class InvalidTransactionError(Exception):
    pass
def make_transfer(amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        return amount
    except ValueError as e:
        raise InvalidTransactionError("Invalid transfer amount.") from e
try:
    print("Transfer:", make_transfer("abc"))
except InvalidTransactionError as e:
    print("ACC-1052:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# ACC-1052: Invalid transfer amount.
# Original cause: ValueError

# %% [markdown]
# ### Q53. Process transfers while isolating bad rows for banking case 3; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1053
transfers = [1000, "bad", 500, -200, 300]
successful = []
failed = []
for amount in transfers:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        successful.append(amount)
    except (ValueError, TypeError) as e:
        failed.append((amount, str(e)))
print("ACC-1053: Successful =", successful)
print("ACC-1053: Failed =", failed)
# Out:
# ACC-1053: Successful = [1000.0, 500.0, 300.0]
# ACC-1053: Failed = [('bad', "could not convert string to float: 'bad'"), (-200.0, 'Amount must be positive')]

# %% [markdown]
# ### Q54. Retry a transient payment gateway for banking case 3; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1054
class TemporaryGatewayError(Exception):
    pass
attempts = 0
max_attempts = 3
while attempts < max_attempts:
    attempts += 1
    try:
        if attempts < 3:
            raise TemporaryGatewayError("Gateway temporarily unavailable")
        print("ACC-1054: Payment successful on attempt", attempts)
        break
    except TemporaryGatewayError as e:
        print("ACC-1054: Attempt", attempts, "failed")
else:
    print("ACC-1054: Payment failed after retries.")
# Out:
# ACC-1054: Attempt 1 failed
# ACC-1054: Attempt 2 failed
# ACC-1054: Payment successful on attempt 3

# %% [markdown]
# ### Q55. Log failed standing instructions for banking case 3; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1055
standing_instructions = [
    ("SI-01", 1000, True),
    ("SI-02", 500, False),
    ("SI-03", 750, True)
]
failed = []
for ref_id, amount, success in standing_instructions:
    try:
        if not success:
            raise RuntimeError("Standing instruction failed")
        print("Processed:", ref_id, amount)
    except RuntimeError as e:
        failed.append((ref_id, str(e)))
print("ACC-1055: Failed instructions =", failed)
# Out:
# Processed: SI-01 1000
# Processed: SI-03 750
# ACC-1055: Failed instructions = [('SI-02', 'Standing instruction failed')]

# %% [markdown]
# ### Q56. Return a structured failure result for banking case 3; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1056
def withdraw(balance, amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > balance:
            raise ValueError("Insufficient funds")
        return {"status": "success", "balance": balance - amount}
    except (ValueError, TypeError) as e:
        return {"status": "failed", "error": str(e)}
print("ACC-1056:", withdraw(5000, 6000))
# Out:
# ACC-1056: {'status': 'failed', 'error': 'Insufficient funds'}

# %% [markdown]
# ### Q57. Validate a nested beneficiary record for banking case 3; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1057
beneficiary = {
    "details": {"name": "Ravi", "account": "ACC-2001"}
}
try:
    name = beneficiary["details"]["name"]
    account = beneficiary["details"]["account"]
    if not name or not account:
        raise ValueError("Beneficiary details are incomplete.")
    print("ACC-1057: Beneficiary valid:", name, account)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1057:", e)
# Out:
# ACC-1057: Beneficiary valid: Ravi ACC-2001

# %% [markdown]
# ### Q58. Use a context manager for an audit file for banking case 3; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1058
file_name = "ACC-1058_audit.txt"
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write("Audit entry for ACC-1058\n")
    print("ACC-1058: Audit file handled safely.")
except OSError as e:
    print("ACC-1058: File error -", e)
# Out:
# ACC-1058: Audit file handled safely.

# %% [markdown]
# ### Q59. Separate validation and recovery for banking case 3; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1059
def validate_amount(value):
    try:
        value = float(value)
        if value <= 0:
            raise ValueError("Amount must be positive")
        return value
    except (ValueError, TypeError) as e:
        print("ACC-1059: Validation failed -", e)
        return None
def recover_amount(value):
    amount = validate_amount(value)
    if amount is None:
        print("ACC-1059: Recovery: transaction cancelled safely.")
        return False
    print("ACC-1059: Recovery not needed. Amount =", amount)
    return True
recover_amount("-100")
# Out:
# ACC-1059: Validation failed - Amount must be positive
# ACC-1059: Recovery: transaction cancelled safely.
# False

# %% [markdown]
# ### Q60. Collect all kyc validation errors for banking case 3; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1060
kyc = {"name": "", "age": 15, "pan": ""}
errors = []
if not kyc.get("name"):
    errors.append("Name is required")
if not isinstance(kyc.get("age"), int) or kyc["age"] < 18:
    errors.append("Age must be 18 or above")
if not kyc.get("pan"):
    errors.append("PAN is required")
if errors:
    print("ACC-1060: KYC errors =", errors)
else:
    print("ACC-1060: KYC validation passed.")
# Out:
# ACC-1060: KYC errors = ['Name is required', 'Age must be 18 or above', 'PAN is required']

# %% [markdown]
# ### Q61. Create insufficientfundserror for banking case 4; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1061
class InsufficientFundsError(Exception):
    pass
balance = 5000
withdrawal = 6000
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("ACC-1061:", e)
# Out:
# ACC-1061: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1062
class InvalidTransactionError(Exception):
    pass
def make_transfer(amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        return amount
    except ValueError as e:
        raise InvalidTransactionError("Invalid transfer amount.") from e
try:
    print("Transfer:", make_transfer("abc"))
except InvalidTransactionError as e:
    print("ACC-1062:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# ACC-1062: Invalid transfer amount.
# Original cause: ValueError

# %% [markdown]
# ### Q63. Process transfers while isolating bad rows for banking case 4; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1063
transfers = [1000, "bad", 500, -200, 300]
successful = []
failed = []
for amount in transfers:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        successful.append(amount)
    except (ValueError, TypeError) as e:
        failed.append((amount, str(e)))
print("ACC-1063: Successful =", successful)
print("ACC-1063: Failed =", failed)
# Out:
# ACC-1063: Successful = [1000.0, 500.0, 300.0]
# ACC-1063: Failed = [('bad', "could not convert string to float: 'bad'"), (-200.0, 'Amount must be positive')]

# %% [markdown]
# ### Q64. Retry a transient payment gateway for banking case 4; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1064
class TemporaryGatewayError(Exception):
    pass
attempts = 0
max_attempts = 3
while attempts < max_attempts:
    attempts += 1
    try:
        if attempts < 3:
            raise TemporaryGatewayError("Gateway temporarily unavailable")
        print("ACC-1064: Payment successful on attempt", attempts)
        break
    except TemporaryGatewayError as e:
        print("ACC-1064: Attempt", attempts, "failed")
else:
    print("ACC-1064: Payment failed after retries.")
# Out:
# ACC-1064: Attempt 1 failed
# ACC-1064: Attempt 2 failed
# ACC-1064: Payment successful on attempt 3

# %% [markdown]
# ### Q65. Log failed standing instructions for banking case 4; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1065
standing_instructions = [
    ("SI-01", 1000, True),
    ("SI-02", 500, False),
    ("SI-03", 750, True)
]
failed = []
for ref_id, amount, success in standing_instructions:
    try:
        if not success:
            raise RuntimeError("Standing instruction failed")
        print("Processed:", ref_id, amount)
    except RuntimeError as e:
        failed.append((ref_id, str(e)))
print("ACC-1065: Failed instructions =", failed)
# Out:
# Processed: SI-01 1000
# Processed: SI-03 750
# ACC-1065: Failed instructions = [('SI-02', 'Standing instruction failed')]

# %% [markdown]
# ### Q66. Return a structured failure result for banking case 4; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1066
def withdraw(balance, amount):
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Amount must be positive")
        if amount > balance:
            raise ValueError("Insufficient funds")
        return {"status": "success", "balance": balance - amount}
    except (ValueError, TypeError) as e:
        return {"status": "failed", "error": str(e)}
print("ACC-1066:", withdraw(5000, 6000))
# Out:
# ACC-1066: {'status': 'failed', 'error': 'Insufficient funds'}

# %% [markdown]
# ### Q67. Validate a nested beneficiary record for banking case 4; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1067
beneficiary = {
    "details": {"name": "Ravi", "account": "ACC-2001"}
}
try:
    name = beneficiary["details"]["name"]
    account = beneficiary["details"]["account"]
    if not name or not account:
        raise ValueError("Beneficiary details are incomplete.")
    print("ACC-1067: Beneficiary valid:", name, account)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1067:", e)
# Out:
# ACC-1067: Beneficiary valid: Ravi ACC-2001

# %% [markdown]
# ### Q68. Use a context manager for an audit file for banking case 4; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1068
file_name = "ACC-1068_audit.txt"
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write("Audit entry for ACC-1068\n")
    print("ACC-1068: Audit file handled safely.")
except OSError as e:
    print("ACC-1068: File error -", e)
# Out:
# ACC-1068: Audit file handled safely.

# %% [markdown]
# ### Q69. Separate validation and recovery for banking case 4; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1069
def validate_amount(value):
    try:
        value = float(value)
        if value <= 0:
            raise ValueError("Amount must be positive")
        return value
    except (ValueError, TypeError) as e:
        print("ACC-1069: Validation failed -", e)
        return None
def recover_amount(value):
    amount = validate_amount(value)
    if amount is None:
        print("ACC-1069: Recovery: transaction cancelled safely.")
        return False
    print("ACC-1069: Recovery not needed. Amount =", amount)
    return True
recover_amount("-100")
# Out:
# ACC-1069: Validation failed - Amount must be positive
# ACC-1069: Recovery: transaction cancelled safely.
# False

# %% [markdown]
# ### Q70. Collect all kyc validation errors for banking case 4; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1070
kyc = {"name": "", "age": 15, "pan": ""}
errors = []
if not kyc.get("name"):
    errors.append("Name is required")
if not isinstance(kyc.get("age"), int) or kyc["age"] < 18:
    errors.append("Age must be 18 or above")
if not kyc.get("pan"):
    errors.append("PAN is required")
if errors:
    print("ACC-1070: KYC errors =", errors)
else:
    print("ACC-1070: KYC validation passed.")
# Out:
# ACC-1070: KYC errors = ['Name is required', 'Age must be 18 or above', 'PAN is required']

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a banking exception hierarchy for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1071
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
try:
    raise InsufficientFundsError("Balance is too low.")
except BankingError as e:
    print("ACC-1071:", type(e).__name__, "-", e)
# Out:
# ACC-1071: InsufficientFundsError - Balance is too low.

# %% [markdown]
# ### Q72. Make a transfer rollback-safe for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1072
def transfer(accounts, sender, receiver, amount):
    old_sender = accounts[sender]
    old_receiver = accounts[receiver]
    try:
        if amount > old_sender:
            raise ValueError("Insufficient funds")
        accounts[sender] -= amount
        raise RuntimeError("Receiver update failed")
        accounts[receiver] += amount
    except Exception as e:
        accounts[sender] = old_sender
        accounts[receiver] = old_receiver
        print("ACC-1072: Transfer rolled back -", e)
accounts = {"A": 5000, "B": 2000}
transfer(accounts, "A", "B", 1000)
print("Balances:", accounts)
# Out:
# ACC-1072: Transfer rolled back - Receiver update failed
# Balances: {'A': 5000, 'B': 2000}

# %% [markdown]
# ### Q73. Preserve causes across service layers for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1073
class ServiceError(Exception):
    pass
def database_layer():
    raise ValueError("Invalid account data")

def banking_service():
    try:
        database_layer()
    except ValueError as e:
        raise ServiceError("Banking service failed") from e
try:
    banking_service()
except ServiceError as e:
    print("ACC-1073:", e)
    print("Cause:", type(e.__cause__).__name__, "-", e.__cause__)
# Out:
# ACC-1073: Banking service failed
# Cause: ValueError - Invalid account data

# %% [markdown]
# ### Q74. Implement bounded exponential retry for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1074
import time
class TemporaryError(Exception):
    pass
attempts = 0
max_attempts = 4
while attempts < max_attempts:
    try:
        attempts += 1
        if attempts < 3:
            raise TemporaryError("Temporary gateway error")
        print("ACC-1074: Success on attempt", attempts)
        break
    except TemporaryError as e:
        delay = min(2 ** (attempts - 1), 4)
        print("Attempt", attempts, "failed; retry after", delay, "seconds")
        # time.sleep(delay)
else:
    print("ACC-1074: All retries failed.")
# Out:
# Attempt 1 failed; retry after 1 seconds
# Attempt 2 failed; retry after 2 seconds
# ACC-1074: Success on attempt 3

# %% [markdown]
# ### Q75. Create a transaction context manager for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1075
class Transaction:
    def __enter__(self):
        self.balance = 5000
        print("ACC-1075: Transaction started")
        return self
    def debit(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient funds")
        self.balance -= amount
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("ACC-1075: Rollback because of error")
        else:
            print("ACC-1075: Transaction committed")
        return False
try:
    with Transaction() as tx:
        tx.debit(1000)
        print("Balance:", tx.balance)
except ValueError as e:
    print("ACC-1075:", e)
# Out:
# ACC-1075: Transaction started
# Balance: 4000
# ACC-1075: Transaction committed

# %% [markdown]
# ### Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1076
events = [
    {"id": "P1", "amount": 1000, "valid": True},
    {"id": "P2", "amount": -50, "valid": False},
    {"id": "P3", "amount": 500, "valid": True}
]
dead_letter_queue = []
for event in events:
    try:
        if not event["valid"] or event["amount"] <= 0:
            raise ValueError("Invalid payment event")
        print("Processed:", event["id"])
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({"event": event, "error": str(e)})
print("ACC-1076: Dead-letter queue =", dead_letter_queue)
# Out:
# Processed: P1
# Processed: P3
# ACC-1076: Dead-letter queue = [{'event': {'id': 'P2', 'amount': -50, 'valid': False}, 'error': 'Invalid payment event'}]

# %% [markdown]
# ### Q77. Make batch settlement failure-isolated for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1077
settlements = [1000, 2000, "bad", 500]
results = []
for amount in settlements:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Invalid settlement amount")
        results.append(("success", amount))
    except (ValueError, TypeError) as e:
        results.append(("failed", str(e)))
print("ACC-1077: Settlement results =", results)
# Out:
# ACC-1077: Settlement results = [('success', 1000.0), ('success', 2000.0), ('failed', "could not convert string to float: 'bad'"), ('success', 500.0)]

# %% [markdown]
# ### Q78. Report exact paths in nested statements for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1078
statement = { "customer": {"account": {"holder": "Ravi","address": {"city": ""}}}}
try:
    city = statement["customer"]["account"]["address"]["city"]
    if not city:
        raise ValueError("City is empty")
    print("City:", city)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1078: Path customer.account.address.city ->", e)
# Out:
# ACC-1078: Path customer.account.address.city -> City is empty

# %% [markdown]
# ### Q79. Design idempotent recovery after timeout for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1079
processed_ids = set()
def recover_payment(payment_id, amount):
    if payment_id in processed_ids:
        return "Already processed"
    try:
        if amount <= 0:
            raise ValueError("Invalid amount")
        processed_ids.add(payment_id)
        return "Payment processed"
    except TimeoutError:
        return "Retry later"
print("ACC-1079:", recover_payment("TXN-01", 1000))
print("ACC-1079:", recover_payment("TXN-01", 1000))
# Out:
# ACC-1079: Payment processed
# ACC-1079: Already processed

# %% [markdown]
# ### Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1080
records = [
    {"id": "R1", "amount": 1000, "matched": True},
    {"id": "R2", "amount": 500, "matched": False},
    {"id": "R3", "amount": 750, "matched": True}
]
matched = []
unmatched = []
for record in records:
    try:
        if not record["matched"]:
            raise ValueError("Record does not reconcile")
        matched.append(record["id"])
    except (KeyError, ValueError) as e:
        unmatched.append((record["id"], str(e)))
print("ACC-1080: Matched =", matched)
print("ACC-1080: Unmatched =", unmatched)
# Out:
# ACC-1080: Matched = ['R1', 'R3']
# ACC-1080: Unmatched = [('R2', 'Record does not reconcile')]

# %% [markdown]
# ### Q81. Design a banking exception hierarchy for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1081
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
try:
    raise InsufficientFundsError("Balance is too low.")
except BankingError as e:
    print("ACC-1081:", type(e).__name__, "-", e)
# Out:
# ACC-1081: InsufficientFundsError - Balance is too low.

# %% [markdown]
# ### Q82. Make a transfer rollback-safe for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1082
def transfer(accounts, sender, receiver, amount):
    old_sender = accounts[sender]
    old_receiver = accounts[receiver]
    try:
        if amount > old_sender:
            raise ValueError("Insufficient funds")
        accounts[sender] -= amount
        raise RuntimeError("Receiver update failed")
        accounts[receiver] += amount
    except Exception as e:
        accounts[sender] = old_sender
        accounts[receiver] = old_receiver
        print("ACC-1082: Transfer rolled back -", e)
accounts = {"A": 5000, "B": 2000}
transfer(accounts, "A", "B", 1000)
print("Balances:", accounts)
# Out:
# ACC-1082: Transfer rolled back - Receiver update failed
# Balances: {'A': 5000, 'B': 2000}

# %% [markdown]
# ### Q83. Preserve causes across service layers for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1083
class ServiceError(Exception):
    pass
def database_layer():
    raise ValueError("Invalid account data")
def banking_service():
    try:
        database_layer()
    except ValueError as e:
        raise ServiceError("Banking service failed") from e
try:
    banking_service()
except ServiceError as e:
    print("ACC-1083:", e)
    print("Cause:", type(e.__cause__).__name__, "-", e.__cause__)
# Out:
# ACC-1083: Banking service failed
# Cause: ValueError - Invalid account data

# %% [markdown]
# ### Q84. Implement bounded exponential retry for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1084
import time
class TemporaryError(Exception):
    pass
attempts = 0
max_attempts = 4
while attempts < max_attempts:
    try:
        attempts += 1
        if attempts < 3:
            raise TemporaryError("Temporary gateway error")
        print("ACC-1084: Success on attempt", attempts)
        break
    except TemporaryError as e:
        delay = min(2 ** (attempts - 1), 4)
        print("Attempt", attempts, "failed; retry after", delay, "seconds")
        # time.sleep(delay)
else:
    print("ACC-1084: All retries failed.")

# %% [markdown]
# ### Q85. Create a transaction context manager for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1085
class Transaction:
    def __enter__(self):
        self.balance = 5000
        print("ACC-1085: Transaction started")
        return self
    def debit(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient funds")
        self.balance -= amount
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("ACC-1085: Rollback because of error")
        else:
            print("ACC-1085: Transaction committed")
        return False
try:
    with Transaction() as tx:
        tx.debit(1000)
        print("Balance:", tx.balance)
except ValueError as e:
    print("ACC-1085:", e)
# Out:
# ACC-1085: Transaction started
# Balance: 4000
# ACC-1085: Transaction committed

# %% [markdown]
# ### Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1086
events = [
    {"id": "P1", "amount": 1000, "valid": True},
    {"id": "P2", "amount": -50, "valid": False},
    {"id": "P3", "amount": 500, "valid": True}
]
dead_letter_queue = []
for event in events:
    try:
        if not event["valid"] or event["amount"] <= 0:
            raise ValueError("Invalid payment event")
        print("Processed:", event["id"])
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({"event": event, "error": str(e)})

print("ACC-1086: Dead-letter queue =", dead_letter_queue)
# Out:
# Processed: P1
# Processed: P3
# ACC-1086: Dead-letter queue = [{'event': {'id': 'P2', 'amount': -50, 'valid': False}, 'error': 'Invalid payment event'}]

# %% [markdown]
# ### Q87. Make batch settlement failure-isolated for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1087
settlements = [1000, 2000, "bad", 500]
results = []
for amount in settlements:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Invalid settlement amount")
        results.append(("success", amount))
    except (ValueError, TypeError) as e:
        results.append(("failed", str(e)))

print("ACC-1087: Settlement results =", results)
# Out:
# ACC-1087: Settlement results = [('success', 1000.0), ('success', 2000.0), ('failed', "could not convert string to float: 'bad'"), ('success', 500.0)]

# %% [markdown]
# ### Q88. Report exact paths in nested statements for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1088
statement = {
    "customer": {
        "account": {
            "holder": "Ravi",
            "address": {"city": ""}
        }
    }
}
try:
    city = statement["customer"]["account"]["address"]["city"]
    if not city:
        raise ValueError("City is empty")
    print("City:", city)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1088: Path customer.account.address.city ->", e)
# Out:
# ACC-1088: Path customer.account.address.city -> City is empty

# %% [markdown]
# ### Q89. Design idempotent recovery after timeout for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1089
processed_ids = set()
def recover_payment(payment_id, amount):
    if payment_id in processed_ids:
        return "Already processed"
    try:
        if amount <= 0:
            raise ValueError("Invalid amount")
        processed_ids.add(payment_id)
        return "Payment processed"
    except TimeoutError:
        return "Retry later"
print("ACC-1089:", recover_payment("TXN-01", 1000))
print("ACC-1089:", recover_payment("TXN-01", 1000))
# Out:
# ACC-1089: Payment processed
# ACC-1089: Already processed

# %% [markdown]
# ### Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1090
records = [
    {"id": "R1", "amount": 1000, "matched": True},
    {"id": "R2", "amount": 500, "matched": False},
    {"id": "R3", "amount": 750, "matched": True}
]
matched = []
unmatched = []
for record in records:
    try:
        if not record["matched"]:
            raise ValueError("Record does not reconcile")
        matched.append(record["id"])
    except (KeyError, ValueError) as e:
        unmatched.append((record["id"], str(e)))
print("ACC-1090: Matched =", matched)
print("ACC-1090: Unmatched =", unmatched)
# Out:
# ACC-1090: Matched = ['R1', 'R3']
# ACC-1090: Unmatched = [('R2', 'Record does not reconcile')]

# %% [markdown]
# ### Q91. Design a banking exception hierarchy for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1091
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
try:
    raise InsufficientFundsError("Balance is too low.")
except BankingError as e:
    print("ACC-1091:", type(e).__name__, "-", e)
# Out:
# ACC-1091: InsufficientFundsError - Balance is too low.

# %% [markdown]
# ### Q92. Make a transfer rollback-safe for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1092
def transfer(accounts, sender, receiver, amount):
    old_sender = accounts[sender]
    old_receiver = accounts[receiver]
    try:
        if amount > old_sender:
            raise ValueError("Insufficient funds")
        accounts[sender] -= amount
        raise RuntimeError("Receiver update failed")
        accounts[receiver] += amount
    except Exception as e:
        accounts[sender] = old_sender
        accounts[receiver] = old_receiver
        print("ACC-1092: Transfer rolled back -", e)
accounts = {"A": 5000, "B": 2000}
transfer(accounts, "A", "B", 1000)
print("Balances:", accounts)
# Out:
# ACC-1092: Transfer rolled back - Receiver update failed
# Balances: {'A': 5000, 'B': 2000}

# %% [markdown]
# ### Q93. Preserve causes across service layers for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1093
class ServiceError(Exception):
    pass
def database_layer():
    raise ValueError("Invalid account data")
def banking_service():
    try:
        database_layer()
    except ValueError as e:
        raise ServiceError("Banking service failed") from e
try:
    banking_service()
except ServiceError as e:
    print("ACC-1093:", e)
    print("Cause:", type(e.__cause__).__name__, "-", e.__cause__)
# Out:
# ACC-1093: Banking service failed
# Cause: ValueError - Invalid account data

# %% [markdown]
# ### Q94. Implement bounded exponential retry for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1094
import time
class TemporaryError(Exception):
    pass
attempts = 0
max_attempts = 4
while attempts < max_attempts:
    try:
        attempts += 1
        if attempts < 3:
            raise TemporaryError("Temporary gateway error")
        print("ACC-1094: Success on attempt", attempts)
        break
    except TemporaryError as e:
        delay = min(2 ** (attempts - 1), 4)
        print("Attempt", attempts, "failed; retry after", delay, "seconds")
        # time.sleep(delay)
else:
    print("ACC-1094: All retries failed.")
# Out:
# Attempt 1 failed; retry after 1 seconds
# Attempt 2 failed; retry after 2 seconds
# ACC-1094: Success on attempt 3

# %% [markdown]
# ### Q95. Create a transaction context manager for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1095
class Transaction:
    def __enter__(self):
        self.balance = 5000
        print("ACC-1095: Transaction started")
        return self
    def debit(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient funds")
        self.balance -= amount
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("ACC-1095: Rollback because of error")
        else:
            print("ACC-1095: Transaction committed")
        return False
try:
    with Transaction() as tx:
        tx.debit(1000)
        print("Balance:", tx.balance)
except ValueError as e:
    print("ACC-1095:", e)
# Out:
# ACC-1095: Transaction started
# Balance: 4000
# ACC-1095: Transaction committed

# %% [markdown]
# ### Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1096
events = [
    {"id": "P1", "amount": 1000, "valid": True},
    {"id": "P2", "amount": -50, "valid": False},
    {"id": "P3", "amount": 500, "valid": True}
]
dead_letter_queue = []
for event in events:
    try:
        if not event["valid"] or event["amount"] <= 0:
            raise ValueError("Invalid payment event")
        print("Processed:", event["id"])
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({"event": event, "error": str(e)})
print("ACC-1096: Dead-letter queue =", dead_letter_queue)
# Out:
# Processed: P1
# Processed: P3
# ACC-1096: Dead-letter queue = [{'event': {'id': 'P2', 'amount': -50, 'valid': False}, 'error': 'Invalid payment event'}]

# %% [markdown]
# ### Q97. Make batch settlement failure-isolated for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1097
settlements = [1000, 2000, "bad", 500]
results = []
for amount in settlements:
    try:
        amount = float(amount)
        if amount <= 0:
            raise ValueError("Invalid settlement amount")
        results.append(("success", amount))
    except (ValueError, TypeError) as e:
        results.append(("failed", str(e)))
print("ACC-1097: Settlement results =", results)
# Out:
# ACC-1097: Settlement results = [('success', 1000.0), ('success', 2000.0), ('failed', "could not convert string to float: 'bad'"), ('success', 500.0)]

# %% [markdown]
# ### Q98. Report exact paths in nested statements for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1098
statement = {
    "customer": {
        "account": {
            "holder": "Ravi",
            "address": {"city": ""}
        }
    }
}
try:
    city = statement["customer"]["account"]["address"]["city"]
    if not city:
        raise ValueError("City is empty")
    print("City:", city)
except (KeyError, TypeError, ValueError) as e:
    print("ACC-1098: Path customer.account.address.city ->", e)
# Out:
# ACC-1098: Path customer.account.address.city -> City is empty

# %% [markdown]
# ### Q99. Design idempotent recovery after timeout for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1099
processed_ids = set()
def recover_payment(payment_id, amount):
    if payment_id in processed_ids:
        return "Already processed"
    try:
        if amount <= 0:
            raise ValueError("Invalid amount")
        processed_ids.add(payment_id)
        return "Payment processed"
    except TimeoutError:
        return "Retry later"
print("ACC-1099:", recover_payment("TXN-01", 1000))
print("ACC-1099:", recover_payment("TXN-01", 1000))
# Out:
# ACC-1099: Payment processed
# ACC-1099: Already processed

# %% [markdown]
# ### Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# ACC-1100
records = [
    {"id": "R1", "amount": 1000, "matched": True},
    {"id": "R2", "amount": 500, "matched": False},
    {"id": "R3", "amount": 750, "matched": True}
]
matched = []
unmatched = []
for record in records:
    try:
        if not record["matched"]:
            raise ValueError("Record does not reconcile")
        matched.append(record["id"])
    except (KeyError, ValueError) as e:
        unmatched.append((record["id"], str(e)))
print("ACC-1100: Matched =", matched)
print("ACC-1100: Unmatched =", unmatched)
# Out:
# ACC-1100: Matched = ['R1', 'R3']
# ACC-1100: Unmatched = [('R2', 'Record does not reconcile')]
