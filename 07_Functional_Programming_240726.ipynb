# %% [markdown]
# # Python Functional Programming Assignment Solutions
#
# This notebook combines all five sections:
#
# 1. Lambda Expressions (20 Questions)
# 2. map() (20 Questions)
# 3. filter() (20 Questions)
# 4. reduce() (20 Questions)
# 5. Combined lambda, map(), filter(), reduce() (20 Questions)
#
# **Total Questions: 100**

# %% [markdown]
# # Lambda Expressions

# %% [markdown]
# # Lambda Expressions - Questions and Solutions
#
# Section 1 (20 Questions)

# %% [markdown]
# ## Question 1
#
# number = 8
#
# Write a lambda expression to calculate the square of number.

# %%
number=8
square=lambda x:x**2
print(square(number))
# Out:
# 64

# %% [markdown]
# ## Question 2
#
# number = 5
#
# Write a lambda expression to calculate the cube of number.

# %%
number=5
cube=lambda x:x**3
print(cube(number))
# Out:
# 125

# %% [markdown]
# ## Question 3
#
# a=25
# b=17
#
# Add a and b.

# %%
a=25
b=17
add=lambda x,y:x+y
print(add(a,b))
# Out:
# 42

# %% [markdown]
# ## Question 4
#
# a=50
# b=18
#
# Subtract b from a.

# %%
a=50
b=18
sub=lambda x,y:x-y
print(sub(a,b))
# Out:
# 32

# %% [markdown]
# ## Question 5
#
# a=12
# b=9
#
# Multiply.

# %%
a=12
b=9
mul=lambda x,y:x*y
print(mul(a,b))
# Out:
# 108

# %% [markdown]
# ## Question 6
#
# a=100
# b=4
#
# Divide.

# %%
a=100
b=4
div=lambda x,y:x/y
print(div(a,b))
# Out:
# 25.0

# %% [markdown]
# ## Question 7
#
# a=72
# b=91
#
# Larger number.

# %%
a=72
b=91
largest=lambda x,y:x if x>y else y
print(largest(a,b))
# Out:
# 91

# %% [markdown]
# ## Question 8
#
# a=46
# b=28
#
# Smaller number.

# %%
a=46
b=28
smallest=lambda x,y:x if x<y else y
print(smallest(a,b))
# Out:
# 28

# %% [markdown]
# ## Question 9
#
# number=34
#
# Even check.

# %%
number=34
even=lambda x:x%2==0
print(even(number))
# Out:
# True

# %% [markdown]
# ## Question 10
#
# number=27
#
# Odd check.

# %%
number=27
odd=lambda x:x%2!=0
print(odd(number))
# Out:
# True

# %% [markdown]
# ## Question 11
#
# length=12
# width=8
# Write a lambda expression to calculate the area of a rectangle.

# %%
length=12
width=8
area=lambda l,w:l*w
print(area(length,width))
# Out:
# 96

# %% [markdown]
# ## Question 12
#
# radius=7
#
# Circle area.

# %%
radius=7
circle=lambda r:3.14*r*r
print(circle(radius))
# Out:
# 153.86

# %% [markdown]
# ## Question 13
#
# length=15
# width=10
# Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length=15
width=10
peri=lambda l,w:2*(l+w)
print(peri(length,width))
# Out:
# 50

# %% [markdown]
# ## Question 14
#
# celsius=35
#
# To Fahrenheit.

# %%
celsius=35
f=lambda c:(c*9/5)+32
print(f(celsius))
# Out:
# 95.0

# %% [markdown]
# ## Question 15
#
# fahrenheit=104
#
# To Celsius.

# %%
fahrenheit=104
c=lambda f:(f-32)*5/9
print(c(fahrenheit))
# Out:
# 40.0

# %% [markdown]
# ## Question 16
#
# word="Python"
#
# Length.

# %%
word="Python"
length=lambda s:len(s)
print(length(word))
# Out:
# 6

# %% [markdown]
# ## Question 17
#
# word="Azure"
#
# First character.

# %%
word="Azure"
first=lambda s:s[0]
print(first(word))
# Out:
# A

# %% [markdown]
# ## Question 18
#
# word="Databricks"
#
# Last character.

# %%
word="Databricks"
last=lambda s:s[-1]
print(last(word))
# Out:
# s

# %% [markdown]
# ## Question 19
#
# number=-45
#
# Absolute value.

# %%
number=-45
absolute=lambda x:x if x>=0 else -x
print(absolute(number))
# Out:
# 45

# %% [markdown]
# ## Question 20
#
# marks=72
#
# Grade.

# %%
marks=72
result=lambda m:'Distinction' if m>=75 else ('Pass' if m>=40 else 'Fail')
print(result(marks))
# Out:
# Pass

# %% [markdown]
# # map()

# %% [markdown]
# # Map() Questions and Solutions
#
# Section 2 (20 Questions)

# %% [markdown]
# ## Question 1
#
# numbers=[1,2,3,4,5,6]
#
# Using map(), calculate the square of every number.

# %%
numbers=[1,2,3,4,5,6]
result=list(map(lambda x:x**2,numbers))
print(result)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# ## Question 2
#
# numbers=[2,3,4,5,6]
#
# Calculate the cube of every number.

# %%
numbers=[2,3,4,5,6]
result=list(map(lambda x:x**3,numbers))
print(result)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# ## Question 3
#
# numbers=[10,20,30,40,50]
#
# Add 5 to every number.

# %%
numbers=[10,20,30,40,50]
result=list(map(lambda x:x+5,numbers))
print(result)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# ## Question 4
#
# numbers=[15,25,35,45,55]
#
# Subtract 10 from every number.

# %%
numbers=[15,25,35,45,55]
result=list(map(lambda x:x-10,numbers))
result
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# ## Question 5
#
# numbers=[1,5,10,15,20]
#
# Multiply every number by 100.

# %%
numbers=[1,5,10,15,20]
result=list(map(lambda x:x*100,numbers))
result
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# ## Question 6
#
# names=["ravi","anil","meena","kiran","sneha"]
#
# Convert to uppercase.

# %%
names=["ravi","anil","meena","kiran","sneha"]
print(list(map(lambda x:x.upper(),names)))
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# ## Question 7
#
# names=["RAHUL","DIVYA","ARJUN","AJAY"]
#
# Convert to lowercase.

# %%
names=["RAHUL","DIVYA","ARJUN","AJAY"]
print(list(map(lambda x:x.lower(),names)))
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# ## Question 8
#
# names=["rahul kumar","anil sharma","meena reddy","divya singh"]
#
# Convert to title case.

# %%
names=["rahul kumar","anil sharma","meena reddy","divya singh"]
print(list(map(lambda x:x.title(),names)))
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# ## Question 9
#
# words=["Python","Azure","Databricks","Cloud","AI"]
#
# Length of every word.

# %%
words=["Python","Azure","Databricks","Cloud","AI"]
print(list(map(len,words)))
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# ## Question 10
#
# words=["Python","Azure","Docker","Linux","Spark"]
#
# First character.

# %%
words=["Python","Azure","Docker","Linux","Spark"]
print(list(map(lambda x:x[0],words)))
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# ## Question 11
#
# words=["Python","Azure","Docker","Linux","Spark"]
#
# Last character.

# %%
words=["Python","Azure","Docker","Linux","Spark"]
print(list(map(lambda x:x[-1],words)))
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# ## Question 12
#
# temperatures=[0,10,20,30,40]
#
# Convert Celsius to Fahrenheit.

# %%
temperatures=[0,10,20,30,40]
print(list(map(lambda c:(c*9/5)+32,temperatures)))
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# ## Question 13
#
# prices=[100,250,500,1000,2500]
#
# Calculate 18% GST.

# %%
prices=[100,250,500,1000,2500]
print(list(map(lambda p:p*0.18,prices)))
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# ## Question 14
#
# prices=[100,250,500,1000,2500]
#
# Final price after GST.

# %%
prices=[100,250,500,1000,2500]
print(list(map(lambda p:p*1.18,prices)))
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# ## Question 15
#
# decimal_numbers=[12.4567,45.8976,78.1234,99.9999]
#
# Round to 2 decimals.

# %%
decimal_numbers=[12.4567,45.8976,78.1234,99.9999]
print(list(map(lambda x:round(x,2),decimal_numbers)))
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# ## Question 16
#
# values=[-10,20,-35,40,-55,60]
#
# Absolute values.

# %%
values=[-10,20,-35,40,-55,60]
print(list(map(abs,values)))
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# ## Question 17
#
# numbers=[10,20,30,40,50]
#
# Convert integers to strings.

# %%
numbers=[10,20,30,40,50]
print(list(map(str,numbers)))
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# ## Question 18
#
# names=["  Ravi  "," Anil","Meena ","  Kiran "]
#
# Strip spaces.

# %%
names=["  Ravi  "," Anil","Meena ","  Kiran "]
print(list(map(lambda x:x.strip(),names)))
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# ## Question 19
#
# Extract employee names using map().

# %%
employees=[{"id":101,"name":"Rahul","salary":45000},
           {"id":102,"name":"Anil","salary":65000},
           {"id":103,"name":"Sneha","salary":72000},
           {"id":104,"name":"Kiran","salary":82000}]
print(list(map(lambda e:e["name"],employees)))
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# ## Question 20
#
# Create new dictionaries with name, original salary and 10% incremented salary.

# %%
employees=[{"id":101,"name":"Rahul","salary":45000},
           {"id":102,"name":"Anil","salary":65000},
           {"id":103,"name":"Sneha","salary":72000},
           {"id":104,"name":"Kiran","salary":82000}]
result=list(map(lambda e:{"name":e["name"],"salary":e["salary"],"new_salary":e["salary"]*1.10},employees))
result
# Out:
# [{'name': 'Rahul', 'salary': 45000, 'new_salary': 49500.00000000001},
#  {'name': 'Anil', 'salary': 65000, 'new_salary': 71500.0},
#  {'name': 'Sneha', 'salary': 72000, 'new_salary': 79200.0},
#  {'name': 'Kiran', 'salary': 82000, 'new_salary': 90200.00000000001}]

# %% [markdown]
# # filter()

# %% [markdown]
# # Filter() Questions and Solutions
#
# Section 3 (20 Questions)

# %% [markdown]
# ## Question 1
#
# Extract all even numbers.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
print(list(filter(lambda x:x%2==0,numbers)))
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# ## Question 2
#
# Extract all odd numbers.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
print(list(filter(lambda x:x%2!=0,numbers)))
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# ## Question 3
#
# Extract numbers greater than 50.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
print(list(filter(lambda x:x>50,numbers)))
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# ## Question 4
#
# Extract numbers less than 100.

# %%
numbers=[120,45,167,89,230,56,91,34,178,100]
print(list(filter(lambda x:x<100,numbers)))
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# ## Question 5
#
# Extract positive numbers.

# %%
numbers=[-15,-8,0,4,12,-25,37,42]
print(list(filter(lambda x:x>0,numbers)))
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# ## Question 6
#
# Extract negative numbers.

# %%
numbers=[-15,-8,0,4,12,-25,37,42]
print(list(filter(lambda x:x<0,numbers)))
# Out:
# [-15, -8, -25]

# %% [markdown]
# ## Question 7
#
# Remove all zeros.

# %%
numbers=[-15,-8,0,4,12,0,-25,37,0]
print(list(filter(lambda x:x!=0,numbers)))
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# ## Question 8
#
# Words with more than five characters.

# %%
words=["python","azure","ai","developer","cloud","analytics"]
print(list(filter(lambda x:len(x)>5,words)))
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# ## Question 9
#
# Names beginning with A.

# %%
names=["Anil","Rahul","Ajay","Meena","Arjun","Kiran","Akhil"]
print(list(filter(lambda x:x.startswith("A"),names)))
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# ## Question 10
#
# Names ending with n.

# %%
names=["Kiran","Mohan","Arjun","Rajan","Meena","Varun"]
print(list(filter(lambda x:x.endswith("n"),names)))
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# ## Question 11
#
# Multiples of 5.

# %%
numbers=[10,15,18,20,25,30,32,40,45,50]
print(list(filter(lambda x:x%5==0,numbers)))
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# ## Question 12
#
# Divisible by both 3 and 5.

# %%
numbers=[3,5,10,15,18,30,42,45,60,75]
print(list(filter(lambda x:x%3==0 and x%5==0,numbers)))
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# ## Question 13
#
# Palindrome words.

# %%
words=["madam","python","level","azure","radar","cloud","civic"]
print(list(filter(lambda x:x==x[::-1],words)))
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# ## Question 14
# emails = [
#     "john@gmail.com",
#     "rahul@yahoo.com",
#     "admin@python.com",
#     "support@azure.org",
#     "sales@company.com"
# ]
#
# Emails ending with .com.

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
print(list(filter(lambda x:x.endswith(".com"),emails)))
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# ## Question 15
#
# CSV files.

# %%
files=["sales.csv","employees.xlsx","products.csv","report.pdf","customers.csv","notes.txt"]
print(list(filter(lambda x:x.endswith(".csv"),files)))
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# ## Question 16
#
# Employees with salary >60000.

# %%
employees=[{"name":"Rahul","salary":45000},
           {"name":"Anil","salary":65000},
           {"name":"Sneha","salary":72000},
           {"name":"Kiran","salary":82000},
           {"name":"Meena","salary":55000}]
print(list(filter(lambda e:e["salary"]>60000,employees)))
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# ## Question 17
#
# Students scoring >80.

# %%
students=[{"name":"Ravi","marks":92},
          {"name":"Kiran","marks":68},
          {"name":"Meena","marks":85},
          {"name":"Ajay","marks":48},
          {"name":"Sneha","marks":79}]
print(list(filter(lambda s:s["marks"]>80,students)))
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# ## Question 18
#
# Products in stock.

# %%
products=[{"name":"Laptop","price":55000,"stock":5},
          {"name":"Mouse","price":600,"stock":25},
          {"name":"Keyboard","price":1500,"stock":0},
          {"name":"Monitor","price":18000,"stock":8},
          {"name":"Printer","price":12000,"stock":0}]
print(list(filter(lambda p:p["stock"]>0,products)))

# %% [markdown]
# ## Question 19
#
# People eligible to vote.

# %%
people=[{"name":"Rahul","age":17},
        {"name":"Anil","age":25},
        {"name":"Sneha","age":16},
        {"name":"Kiran","age":32},
        {"name":"Meena","age":18}]
print(list(filter(lambda p:p["age"]>=18,people)))

# %% [markdown]
# ## Question 20
#
# Active IT employees.

# %%
employees=[{"name":"Rahul","department":"IT","active":True},
           {"name":"Anil","department":"HR","active":True},
           {"name":"Sneha","department":"IT","active":False},
           {"name":"Kiran","department":"IT","active":True},
           {"name":"Meena","department":"Sales","active":True}]
print(list(filter(lambda e:e["department"]=="IT" and e["active"],employees)))

# %% [markdown]
# # reduce()

# %% [markdown]
# # Reduce() Questions and Solutions
#
# Section 4 (20 Questions)
#
# > `from functools import reduce` is imported where needed.

# %%
from functools import reduce

# %% [markdown]
# ## Question 1
#
# Sum of all numbers using reduce().

# %%
numbers=[10,20,30,40,50]
print(reduce(lambda a,b:a+b,numbers))
# Out:
# 150

# %% [markdown]
# ## Question 2
#
# Product of all numbers.

# %%
numbers=[2,3,4,5]
print(reduce(lambda a,b:a*b,numbers))
# Out:
# 120

# %% [markdown]
# ## Question 3
#
# Find maximum number.

# %%
numbers=[45,12,89,34,67,91,28]
print(reduce(lambda a,b:a if a>b else b,numbers))
# Out:
# 91

# %% [markdown]
# ## Question 4
#
# Find minimum number.

# %%
numbers=[45,12,89,34,67,91,28]
print(reduce(lambda a,b:a if a<b else b,numbers))
# Out:
# 12

# %% [markdown]
# ## Question 5
#
# Join all strings.

# %%
words=["Python"," ","is"," ","powerful"]
print(reduce(lambda a,b:a+b,words))
# Out:
# Python is powerful

# %% [markdown]
# ## Question 6
#
# Total characters in all words.

# %%
words=["Python","Azure","Cloud","AI"]
print(reduce(lambda a,b:a+len(b),words[1:],len(words[0])))
# Out:
# 18

# %% [markdown]
# ## Question 7
#
# Factorial of 6.

# %%
number=6
numbers=list(range(1,number+1))
print(reduce(lambda a,b:a*b,numbers))
# Out:
# 720

# %% [markdown]
# ## Question 8
#
# Sum of even numbers.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
print(reduce(lambda a,b:a+(b if b%2==0 else 0),numbers,0))
# Out:
# 280

# %% [markdown]
# ## Question 9
#
# Sum of odd numbers.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
print(reduce(lambda a,b:a+(b if b%2 else 0),numbers,0))
# Out:
# 315

# %% [markdown]
# ## Question 10
#
# Longest word.

# %%
words=["AI","Python","Databricks","Cloud","Kubernetes"]
print(reduce(lambda a,b:a if len(a)>len(b) else b,words))
# Out:
# Kubernetes

# %% [markdown]
# ## Question 11
#
# Shortest word.

# %%
words=["AI","Python","Databricks","Cloud","Kubernetes"]
print(reduce(lambda a,b:a if len(a)<len(b) else b,words))
# Out:
# AI

# %% [markdown]
# ## Question 12
#
# Total salary.

# %%
salaries=[45000,65000,72000,82000,55000]
print(reduce(lambda a,b:a+b,salaries))
# Out:
# 319000

# %% [markdown]
# ## Question 13
#
# Total payroll from dictionaries.

# %%
employees=[{"name":"Rahul","salary":45000},
           {"name":"Anil","salary":65000},
           {"name":"Sneha","salary":72000},
           {"name":"Kiran","salary":82000},
           {"name":"Meena","salary":55000}]
print(reduce(lambda a,e:a+e["salary"],employees,0))
# Out:
# 319000

# %% [markdown]
# ## Question 14
#
# Employee with highest salary.

# %%
employees=[{"name":"Rahul","salary":45000},
           {"name":"Anil","salary":65000},
           {"name":"Sneha","salary":72000},
           {"name":"Kiran","salary":82000},
           {"name":"Meena","salary":55000}]
print(reduce(lambda a,b:a if a["salary"]>b["salary"] else b,employees))
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# ## Question 15
#
# Student with highest marks.

# %%
students=[{"name":"Ravi","marks":92},
          {"name":"Kiran","marks":68},
          {"name":"Meena","marks":85},
          {"name":"Ajay","marks":48},
          {"name":"Rahul","marks":95}]
print(reduce(lambda a,b:a if a["marks"]>b["marks"] else b,students))
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# ## Question 16
#
# Total stock quantity.

# %%
products=[{"name":"Laptop","price":55000,"stock":5},
          {"name":"Mouse","price":600,"stock":25},
          {"name":"Keyboard","price":1500,"stock":15},
          {"name":"Monitor","price":18000,"stock":8}]
print(reduce(lambda a,p:a+p["stock"],products,0))
# Out:
# 53

# %% [markdown]
# ## Question 17
#
# Total inventory value.

# %%
products=[{"name":"Laptop","price":55000,"stock":5},
          {"name":"Mouse","price":600,"stock":25},
          {"name":"Keyboard","price":1500,"stock":15},
          {"name":"Monitor","price":18000,"stock":8}]
print(reduce(lambda a,p:a+p["price"]*p["stock"],products,0))
# Out:
# 456500

# %% [markdown]
# ## Question 18
#
# Total sales amount.

# %%
sales=[12000,25000,18000,45000,30000,52000]
print(reduce(lambda a,b:a+b,sales))
# Out:
# 182000

# %% [markdown]
# ## Question 19
#
# Merge dictionaries.

# %%
dictionaries=[{"name":"Rahul"},{"age":30},
              {"department":"IT"},{"salary":65000}]
print(reduce(lambda a,b:{**a,**b},dictionaries))
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# ## Question 20
#
# Sum of unique numbers.

# %%
numbers=[12,45,12,67,45,89,23,67,100]
seen=set()
print(reduce(lambda a,b:a if (b in seen or seen.add(b)) else a+b,numbers,0))
# Out:
# 336

# %% [markdown]
# # Combined Operations

# %% [markdown]
# # Combined Lambda, map(), filter(), and reduce() Questions & Solutions
#
# Section 5 (20 Questions)

# %% [markdown]
# ## Question 1
#
# Filter even numbers and square them.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
result=list(map(lambda x:x*x,filter(lambda x:x%2==0,numbers)))
print(result)
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# ## Question 2
#
# Filter odd numbers and calculate total sum.

# %%
numbers=[12,45,67,89,23,56,91,34,78,100]
odd=filter(lambda x:x%2!=0,numbers)
print(reduce(lambda a,b:a+b,odd,0))
# Out:
# 315

# %% [markdown]
# ## Question 3
#
# Filter numbers >50 and multiply by 2.

# %%
numbers=[10,25,40,55,70,85,100]
print(list(map(lambda x:x*2,filter(lambda x:x>50,numbers))))
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# ## Question 4
#
# Positive numbers → square → total.

# %%
numbers=[-15,20,-35,40,50,-10,60]
vals=map(lambda x:x*x,filter(lambda x:x>0,numbers))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 8100

# %% [markdown]
# ## Question 5
#
# Words >5 chars → uppercase.

# %%
words=["python","azure","ai","developer","cloud","analytics","spark"]
print(list(map(str.upper,filter(lambda x:len(x)>5,words))))
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# ## Question 6
#
# Names starting with A → lowercase.

# %%
names=["Anil","Rahul","Ajay","Meena","Arjun","Kiran","Akhil"]
print(list(map(str.lower,filter(lambda x:x.startswith("A"),names))))
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# ## Question 7
#
# Divisible by 3 and 5 → sum.

# %%
numbers=[3,5,10,15,18,30,42,45,60,75]
vals=filter(lambda x:x%3==0 and x%5==0,numbers)
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 225

# %% [markdown]
# ## Question 8
#
# Palindrome words joined.

# %%
words=["madam","python","level","azure","radar","cloud","civic"]
vals=filter(lambda x:x==x[::-1],words)
print(reduce(lambda a,b:a+" | "+b,vals))
# Out:
# madam | level | radar | civic

# %% [markdown]
# ## Question 9
#
# Temps>30 → Fahrenheit → average.

# %%
temps=[18,24,30,35,40,12,28,33,15,42]
vals=list(map(lambda c:(c*9/5)+32,filter(lambda x:x>30,temps)))
print(sum(vals)/len(vals))
# Out:
# 99.5

# %% [markdown]
# ## Question 10
#
# Prices>1000 →10% discount→total.

# %%
prices=[450,1200,2500,800,5000,1500,7500]
vals=map(lambda x:x*0.9,filter(lambda x:x>1000,prices))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 15930.0

# %% [markdown]
# ## Question 11
#
# Employees >60000 →10% increment.

# %%
employees=[{"id":101,"name":"Rahul","salary":45000},
           {"id":102,"name":"Anil","salary":65000},
           {"id":103,"name":"Sneha","salary":72000},
           {"id":104,"name":"Kiran","salary":82000},
           {"id":105,"name":"Meena","salary":55000}]
result=list(map(lambda e:{"name":e["name"],"salary":e["salary"]*1.1},filter(lambda e:e["salary"]>60000,employees)))
print(result)
# Out:
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.00000000001}]

# %% [markdown]
# ## Question 12
#
# IT employees total salary.

# %%
employees=[{"department":"IT","salary":45000},
           {"department":"HR","salary":65000},
           {"department":"IT","salary":72000},
           {"department":"IT","salary":82000},
           {"department":"Sales","salary":55000}]
vals=filter(lambda e:e["department"]=="IT",employees)
print(reduce(lambda a,e:a+e["salary"],vals,0))
# Out:
# 199000

# %% [markdown]
# ## Question 13
#
# Active employees +15% salary → payroll.

# %%
employees=[{"salary":45000,"active":True},
           {"salary":65000,"active":True},
           {"salary":72000,"active":False},
           {"salary":82000,"active":True},
           {"salary":55000,"active":True},
           {"salary":98000,"active":False}]
vals=map(lambda e:e["salary"]*1.15,filter(lambda e:e["active"],employees))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 284050.0

# %% [markdown]
# ## Question 14
#
# Passed students topper.

# %%
students=[{"name":"Ravi","marks":92,"passed":True},
          {"name":"Kiran","marks":68,"passed":True},
          {"name":"Meena","marks":85,"passed":True},
          {"name":"Ajay","marks":48,"passed":True},
          {"name":"Sneha","marks":35,"passed":False},
          {"name":"Rahul","marks":95,"passed":True}]
vals=filter(lambda s:s["passed"],students)
print(reduce(lambda a,b:a if a["marks"]>b["marks"] else b,vals))
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# ## Question 15
#
# Students >70 average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
vals=list(map(lambda s:s["marks"],filter(lambda s:s["marks"]>70,students)))
print(sum(vals)/len(vals))
# Out:
# 87.75

# %% [markdown]
# ## Question 16
#
# Inventory value in-stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
vals=map(lambda p:p["price"]*p["stock"],filter(lambda p:p["stock"]>0,products))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 512000

# %% [markdown]
# ## Question 17
#
# Electronics 20% discount total.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
vals=map(lambda p:p["price"]*0.8,filter(lambda p:p["category"]=="Electronics",products))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 63600.0

# %% [markdown]
# ## Question 18
#
# Total Delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
vals=map(lambda o:o["amount"],filter(lambda o:o["status"]=="Delivered",orders))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 17300

# %% [markdown]
# ## Question 19
# Extract transactions whose amount is greater than 5000.
# Add 18% GST to every selected transaction.
# Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]

vals=map(lambda t:t["amount"]*1.18,filter(lambda t:t["amount"]>5000,transactions))
print(reduce(lambda a,b:a+b,vals,0))
# Out:
# 47200.0

# %% [markdown]
# ## Question 20
# 1. Extract active salespeople from the South region.
# 2. Calculate a 5% incentive for each selected salesperson.
# 3. Create a list containing salesperson name, sales amount, and incentive.
# 4. Calculate the total incentive payable.

# %%
sales=[{"salesperson":"Rahul","region":"South","sales":45000,"active":True},
       {"salesperson":"Anil","region":"North","sales":65000,"active":True},
       {"salesperson":"Sneha","region":"South","sales":72000,"active":False},
       {"salesperson":"Kiran","region":"South","sales":82000,"active":True},
       {"salesperson":"Meena","region":"West","sales":55000,"active":True},
       {"salesperson":"Arjun","region":"South","sales":98000,"active":True}]
vals=list(map(lambda s:{"name":s["salesperson"],"sales":s["sales"],"incentive":s["sales"]*0.05},filter(lambda s:s["region"]=="South" and s["active"],sales)))
print(vals)
print("Total Incentive:",reduce(lambda a,b:a+b["incentive"],vals,0))
# Out:
# [{'name': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'name': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'name': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# Total Incentive: 11250.0
